# %% [markdown]
# # Enron Fraud

# %% [markdown]
# ## Initital Load
# ### Import packages:

# %%
import sys
import pickle
import numpy as np
import pandas as pd
from pandas import DataFrame
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import Imputer
from sklearn.ensemble import ExtraTreesClassifier
import seaborn as sns
import matplotlib.pyplot as plt
sys.path.append("../tools/")
# %matplotlib inline
from feature_format import featureFormat, targetFeatureSplit
from tester import dump_classifier_and_data
# Out:
# /anaconda/envs/enron/lib/python2.7/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# ### Load dataset and create dataframe

# %%
features_email = ['to_messages', 'from_messages',  'from_poi_to_this_person',
           'from_this_person_to_poi', 'shared_receipt_with_poi']
# finance data
features_finance = ['salary', 'bonus', 'long_term_incentive', 'deferred_income',
             'deferral_payments', 'loan_advances', 'other', 'expenses',
             'director_fees', 'total_payments',
             'exercised_stock_options', 'restricted_stock',
             'restricted_stock_deferred', 'total_stock_value']
# all features
features_list = features_email + features_finance
# all features column names
features_column_names = ['poi'] + ['email_address'] + features_email + features_finance
# all features data type
features_dtype = [bool] + [str] + list(np.repeat(float, 19))

### Load the dictionary containing the dataset
with open("final_project_dataset.pkl", "r") as data_file:
    data_dict = pickle.load(data_file)

# converting the data into a data frame
df = DataFrame.from_dict(data_dict, orient='index')

# reordering the columns
df = df.loc[:, features_column_names]

# converting the data type
for i in xrange(len(features_column_names)):
    df[features_column_names[i]] = df[features_column_names[i]].astype(features_dtype[i], errors='ignore')

# %% [markdown]
# ## Descriptive analysis & wrangling of dataset

# %% [markdown]
# ### Raw table

# %%
print df
# Out:
#                                  poi                     email_address  \
# ALLEN PHILLIP K                False           phillip.allen@enron.com
# BADUM JAMES P                  False                               NaN
# BANNANTINE JAMES M             False        james.bannantine@enron.com
# BAXTER JOHN C                  False                               NaN
# BAY FRANKLIN R                 False               frank.bay@enron.com
# BAZELIDES PHILIP J             False                               NaN
# BECK SALLY W                   False              sally.beck@enron.com
# BELDEN TIMOTHY N                True              tim.belden@enron.com
# BELFER ROBERT                  False                               NaN
# BERBERIAN DAVID                False         david.berberian@enron.com
# BERGSIEKER RICHARD P           False         rick.bergsieker@enron.com
# BHATNAGAR SANJAY               False        sanjay.bhatnagar@enron.com
# BIBI PHILIPPE A                False           philippe.bibi@enron.com
# BLACHMAN JEREMY M              False         jeremy.blachman@enron.com
# BLAKE JR. NORMAN P             False                               NaN
# BOWEN JR RAYMOND M              True           raymond.bowen@enron.com
# BROWN MICHAEL                  False           michael.brown@enron.com
# BUCHANAN HAROLD G              False           john.buchanan@enron.com
# BUTTS ROBERT H                 False               bob.butts@enron.com
# BUY RICHARD B                  False                rick.buy@enron.com
# CALGER CHRISTOPHER F            True      christopher.calger@enron.com
# CARTER REBECCA C               False          rebecca.carter@enron.com
# CAUSEY RICHARD A                True          richard.causey@enron.com
# CHAN RONNIE                    False                               NaN
# CHRISTODOULOU DIOMEDES         False  diomedes.christodoulou@enron.com
# CLINE KENNETH W                False                               NaN
# COLWELL WESLEY                  True             wes.colwell@enron.com
# CORDES WILLIAM R               False             bill.cordes@enron.com
# COX DAVID                      False                chip.cox@enron.com
# CUMBERLAND MICHAEL S           False                               NaN
# ...                              ...                               ...
# SHANKMAN JEFFREY A             False        jeffrey.shankman@enron.com
# SHAPIRO RICHARD S              False         richard.shapiro@enron.com
# SHARP VICTORIA T               False             vicki.sharp@enron.com
# SHELBY REX                      True              rex.shelby@enron.com
# SHERRICK JEFFREY B             False        jeffrey.sherrick@enron.com
# SHERRIFF JOHN R                False           john.sherriff@enron.com
# SKILLING JEFFREY K              True           jeff.skilling@enron.com
# STABLER FRANK                  False           frank.stabler@enron.com
# SULLIVAN-SHAKLOVITZ COLLEEN    False                               NaN
# SUNDE MARTIN                   False             marty.sunde@enron.com
# TAYLOR MITCHELL S              False         mitchell.taylor@enron.com
# THE TRAVEL AGENCY IN THE PARK  False                               NaN
# THORN TERENCE H                False           terence.thorn@enron.com
# TILNEY ELIZABETH A             False        elizabeth.tilney@enron.com
# TOTAL                          False                               NaN
# UMANOFF ADAM S                 False            adam.umanoff@enron.com
# URQUHART JOHN A                False                               NaN
# WAKEHAM JOHN                   False                               NaN
# WALLS JR ROBERT H              False               rob.walls@enron.com
# WALTERS GARETH W               False                               NaN
# WASAFF GEORGE                  False           george.wasaff@enron.com
# WESTFAHL RICHARD K             False           dick.westfahl@enron.com
# WHALEY DAVID A                 False                               NaN
# WHALLEY LAWRENCE G             False            greg.whalley@enron.com
# WHITE JR THOMAS E              False            thomas.white@enron.com
# WINOKUR JR. HERBERT S          False                               NaN
# WODRASKA JOHN                  False           john.wodraska@enron.com
# WROBEL BRUCE                   False                               NaN
# YEAGER F SCOTT                  True            scott.yeager@enron.com
# YEAP SOON                      False                               NaN
#
#                                to_messages  from_messages  \
# ALLEN PHILLIP K                     2902.0         2195.0
# BADUM JAMES P                          NaN            NaN
# BANNANTINE JAMES M                   566.0           29.0
# BAXTER JOHN C                          NaN            NaN
# BAY FRANKLIN R                         NaN            NaN
# BAZELIDES PHILIP J                     NaN            NaN
# BECK SALLY W                        7315.0         4343.0
# BELDEN TIMOTHY N                    7991.0          484.0
# BELFER ROBERT                          NaN            NaN
# BERBERIAN DAVID                        NaN            NaN
# BERGSIEKER RICHARD P                 383.0           59.0
# BHATNAGAR SANJAY                     523.0           29.0
# BIBI PHILIPPE A                     1607.0           40.0
# BLACHMAN JEREMY M                   2475.0           14.0
# BLAKE JR. NORMAN P                     NaN            NaN
# BOWEN JR RAYMOND M                  1858.0           27.0
# BROWN MICHAEL                       1486.0           41.0
# BUCHANAN HAROLD G                   1088.0          125.0
# BUTTS ROBERT H                         NaN            NaN
# BUY RICHARD B                       3523.0         1053.0
# CALGER CHRISTOPHER F                2598.0          144.0
# CARTER REBECCA C                     312.0           15.0
# CAUSEY RICHARD A                    1892.0           49.0
# CHAN RONNIE                            NaN            NaN
# CHRISTODOULOU DIOMEDES                 NaN            NaN
# CLINE KENNETH W                        NaN            NaN
# COLWELL WESLEY                      1758.0           40.0
# CORDES WILLIAM R                     764.0           12.0
# COX DAVID                            102.0           33.0
# CUMBERLAND MICHAEL S                   NaN            NaN
# ...                                    ...            ...
# SHANKMAN JEFFREY A                  3221.0         2681.0
# SHAPIRO RICHARD S                  15149.0         1215.0
# SHARP VICTORIA T                    3136.0          136.0
# SHELBY REX                           225.0           39.0
# SHERRICK JEFFREY B                   613.0           25.0
# SHERRIFF JOHN R                     3187.0           92.0
# SKILLING JEFFREY K                  3627.0          108.0
# STABLER FRANK                          NaN            NaN
# SULLIVAN-SHAKLOVITZ COLLEEN            NaN            NaN
# SUNDE MARTIN                        2647.0           38.0
# TAYLOR MITCHELL S                    533.0           29.0
# THE TRAVEL AGENCY IN THE PARK          NaN            NaN
# THORN TERENCE H                      266.0           41.0
# TILNEY ELIZABETH A                   460.0           19.0
# TOTAL                                  NaN            NaN
# UMANOFF ADAM S                       111.0           18.0
# URQUHART JOHN A                        NaN            NaN
# WAKEHAM JOHN                           NaN            NaN
# WALLS JR ROBERT H                    671.0          146.0
# WALTERS GARETH W                       NaN            NaN
# WASAFF GEORGE                        400.0           30.0
# WESTFAHL RICHARD K                     NaN            NaN
# WHALEY DAVID A                         NaN            NaN
# WHALLEY LAWRENCE G                  6019.0          556.0
# WHITE JR THOMAS E                      NaN            NaN
# WINOKUR JR. HERBERT S                  NaN            NaN
# WODRASKA JOHN                          NaN            NaN
# WROBEL BRUCE                           NaN            NaN
# YEAGER F SCOTT                         NaN            NaN
# YEAP SOON                              NaN            NaN
#
#                                from_poi_to_this_person  \
# ALLEN PHILLIP K                                   47.0
# BADUM JAMES P                                      NaN
# BANNANTINE JAMES M                                39.0
# BAXTER JOHN C                                      NaN
# BAY FRANKLIN R                                     NaN
# BAZELIDES PHILIP J                                 NaN
# BECK SALLY W                                     144.0
# BELDEN TIMOTHY N                                 228.0
# BELFER ROBERT                                      NaN
# BERBERIAN DAVID                                    NaN
# BERGSIEKER RICHARD P                               4.0
# BHATNAGAR SANJAY                                   0.0
# BIBI PHILIPPE A                                   23.0
# BLACHMAN JEREMY M                                 25.0
# BLAKE JR. NORMAN P                                 NaN
# BOWEN JR RAYMOND M                               140.0
# BROWN MICHAEL                                     13.0
# BUCHANAN HAROLD G                                  0.0
# BUTTS ROBERT H                                     NaN
# BUY RICHARD B                                    156.0
# CALGER CHRISTOPHER F                             199.0
# CARTER REBECCA C                                  29.0
# CAUSEY RICHARD A                                  58.0
# CHAN RONNIE                                        NaN
# CHRISTODOULOU DIOMEDES                             NaN
# CLINE KENNETH W                                    NaN
# COLWELL WESLEY                                   240.0
# CORDES WILLIAM R                                  10.0
# COX DAVID                                          0.0
# CUMBERLAND MICHAEL S                               NaN
# ...                                                ...
# SHANKMAN JEFFREY A                                94.0
# SHAPIRO RICHARD S                                 74.0
# SHARP VICTORIA T                                  24.0
# SHELBY REX                                        13.0
# SHERRICK JEFFREY B                                39.0
# SHERRIFF JOHN R                                   28.0
# SKILLING JEFFREY K                                88.0
# STABLER FRANK                                      NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                        NaN
# SUNDE MARTIN                                      37.0
# TAYLOR MITCHELL S                                  0.0
# THE TRAVEL AGENCY IN THE PARK                      NaN
# THORN TERENCE H                                    0.0
# TILNEY ELIZABETH A                                10.0
# TOTAL                                              NaN
# UMANOFF ADAM S                                    12.0
# URQUHART JOHN A                                    NaN
# WAKEHAM JOHN                                       NaN
# WALLS JR ROBERT H                                 17.0
# WALTERS GARETH W                                   NaN
# WASAFF GEORGE                                     22.0
# WESTFAHL RICHARD K                                 NaN
# WHALEY DAVID A                                     NaN
# WHALLEY LAWRENCE G                               186.0
# WHITE JR THOMAS E                                  NaN
# WINOKUR JR. HERBERT S                              NaN
# WODRASKA JOHN                                      NaN
# WROBEL BRUCE                                       NaN
# YEAGER F SCOTT                                     NaN
# YEAP SOON                                          NaN
#
#                                from_this_person_to_poi  \
# ALLEN PHILLIP K                                   65.0
# BADUM JAMES P                                      NaN
# BANNANTINE JAMES M                                 0.0
# BAXTER JOHN C                                      NaN
# BAY FRANKLIN R                                     NaN
# BAZELIDES PHILIP J                                 NaN
# BECK SALLY W                                     386.0
# BELDEN TIMOTHY N                                 108.0
# BELFER ROBERT                                      NaN
# BERBERIAN DAVID                                    NaN
# BERGSIEKER RICHARD P                               0.0
# BHATNAGAR SANJAY                                   1.0
# BIBI PHILIPPE A                                    8.0
# BLACHMAN JEREMY M                                  2.0
# BLAKE JR. NORMAN P                                 NaN
# BOWEN JR RAYMOND M                                15.0
# BROWN MICHAEL                                      1.0
# BUCHANAN HAROLD G                                  0.0
# BUTTS ROBERT H                                     NaN
# BUY RICHARD B                                     71.0
# CALGER CHRISTOPHER F                              25.0
# CARTER REBECCA C                                   7.0
# CAUSEY RICHARD A                                  12.0
# CHAN RONNIE                                        NaN
# CHRISTODOULOU DIOMEDES                             NaN
# CLINE KENNETH W                                    NaN
# COLWELL WESLEY                                    11.0
# CORDES WILLIAM R                                   0.0
# COX DAVID                                          4.0
# CUMBERLAND MICHAEL S                               NaN
# ...                                                ...
# SHANKMAN JEFFREY A                                83.0
# SHAPIRO RICHARD S                                 65.0
# SHARP VICTORIA T                                   6.0
# SHELBY REX                                        14.0
# SHERRICK JEFFREY B                                18.0
# SHERRIFF JOHN R                                   23.0
# SKILLING JEFFREY K                                30.0
# STABLER FRANK                                      NaN
# SULLIVAN-SHAKLOVITZ COLLEEN                        NaN
# SUNDE MARTIN                                      13.0
# TAYLOR MITCHELL S                                  0.0
# THE TRAVEL AGENCY IN THE PARK                      NaN
# THORN TERENCE H                                    0.0
# TILNEY ELIZABETH A                                11.0
# TOTAL                                              NaN
# UMANOFF ADAM S                                     0.0
# URQUHART JOHN A                                    NaN
# WAKEHAM JOHN                                       NaN
# WALLS JR ROBERT H                                  0.0
# WALTERS GARETH W                                   NaN
# WASAFF GEORGE                                      7.0
# WESTFAHL RICHARD K                                 NaN
# WHALEY DAVID A                                     NaN
# WHALLEY LAWRENCE G                                24.0
# WHITE JR THOMAS E                                  NaN
# WINOKUR JR. HERBERT S                              NaN
# WODRASKA JOHN                                      NaN
# WROBEL BRUCE                                       NaN
# YEAGER F SCOTT                                     NaN
# YEAP SOON                                          NaN
#
#                                shared_receipt_with_poi      salary  \
# ALLEN PHILLIP K                                 1407.0    201955.0
# BADUM JAMES P                                      NaN         NaN
# BANNANTINE JAMES M                               465.0       477.0
# BAXTER JOHN C                                      NaN    267102.0
# BAY FRANKLIN R                                     NaN    239671.0
# BAZELIDES PHILIP J                                 NaN     80818.0
# BECK SALLY W                                    2639.0    231330.0
# BELDEN TIMOTHY N                                5521.0    213999.0
# BELFER ROBERT                                      NaN         NaN
# BERBERIAN DAVID                                    NaN    216582.0
# BERGSIEKER RICHARD P                             233.0    187922.0
# BHATNAGAR SANJAY                                 463.0         NaN
# BIBI PHILIPPE A                                 1336.0    213625.0
# BLACHMAN JEREMY M                               2326.0    248546.0
# BLAKE JR. NORMAN P                                 NaN         NaN
# BOWEN JR RAYMOND M                              1593.0    278601.0
# BROWN MICHAEL                                    761.0         NaN
# BUCHANAN HAROLD G                                 23.0    248017.0
# BUTTS ROBERT H                                     NaN    261516.0
# BUY RICHARD B                                   2333.0    330546.0
# CALGER CHRISTOPHER F                            2188.0    240189.0
# CARTER REBECCA C                                 196.0    261809.0
# CAUSEY RICHARD A                                1585.0    415189.0
# CHAN RONNIE                                        NaN         NaN
# CHRISTODOULOU DIOMEDES                             NaN         NaN
# CLINE KENNETH W                                    NaN         NaN
# COLWELL WESLEY                                  1132.0    288542.0
# CORDES WILLIAM R                                  58.0         NaN
# COX DAVID                                         71.0    314288.0
# CUMBERLAND MICHAEL S                               NaN    184899.0
# ...                                                ...         ...
# SHANKMAN JEFFREY A                              1730.0    304110.0
# SHAPIRO RICHARD S                               4527.0    269076.0
# SHARP VICTORIA T                                2477.0    248146.0
# SHELBY REX                                        91.0    211844.0
# SHERRICK JEFFREY B                               583.0         NaN
# SHERRIFF JOHN R                                 2103.0    428780.0
# SKILLING JEFFREY K                              2042.0   1111258.0
# STABLER FRANK                                      NaN    239502.0
# SULLIVAN-SHAKLOVITZ COLLEEN                        NaN    162779.0
# SUNDE MARTIN                                    2565.0    257486.0
# TAYLOR MITCHELL S                                300.0    265214.0
# THE TRAVEL AGENCY IN THE PARK                      NaN         NaN
# THORN TERENCE H                                   73.0    222093.0
# TILNEY ELIZABETH A                               379.0    247338.0
# TOTAL                                              NaN  26704229.0
# UMANOFF ADAM S                                    41.0    288589.0
# URQUHART JOHN A                                    NaN         NaN
# WAKEHAM JOHN                                       NaN         NaN
# WALLS JR ROBERT H                                215.0    357091.0
# WALTERS GARETH W                                   NaN         NaN
# WASAFF GEORGE                                    337.0    259996.0
# WESTFAHL RICHARD K                                 NaN     63744.0
# WHALEY DAVID A                                     NaN         NaN
# WHALLEY LAWRENCE G                              3920.0    510364.0
# WHITE JR THOMAS E                                  NaN    317543.0
# WINOKUR JR. HERBERT S                              NaN         NaN
# WODRASKA JOHN                                      NaN         NaN
# WROBEL BRUCE                                       NaN         NaN
# YEAGER F SCOTT                                     NaN    158403.0
# YEAP SOON                                          NaN         NaN
#
#                                     bonus  long_term_incentive  \
# ALLEN PHILLIP K                 4175000.0             304805.0
# BADUM JAMES P                         NaN                  NaN
# BANNANTINE JAMES M                    NaN                  NaN
# BAXTER JOHN C                   1200000.0            1586055.0
# BAY FRANKLIN R                   400000.0                  NaN
# BAZELIDES PHILIP J                    NaN              93750.0
# BECK SALLY W                     700000.0                  NaN
# BELDEN TIMOTHY N                5249999.0                  NaN
# BELFER ROBERT                         NaN                  NaN
# BERBERIAN DAVID                       NaN                  NaN
# BERGSIEKER RICHARD P             250000.0             180250.0
# BHATNAGAR SANJAY                      NaN                  NaN
# BIBI PHILIPPE A                 1000000.0             369721.0
# BLACHMAN JEREMY M                850000.0             831809.0
# BLAKE JR. NORMAN P                    NaN                  NaN
# BOWEN JR RAYMOND M              1350000.0             974293.0
# BROWN MICHAEL                         NaN                  NaN
# BUCHANAN HAROLD G                500000.0             304805.0
# BUTTS ROBERT H                   750000.0             175000.0
# BUY RICHARD B                    900000.0             769862.0
# CALGER CHRISTOPHER F            1250000.0             375304.0
# CARTER REBECCA C                 300000.0              75000.0
# CAUSEY RICHARD A                1000000.0             350000.0
# CHAN RONNIE                           NaN                  NaN
# CHRISTODOULOU DIOMEDES                NaN                  NaN
# CLINE KENNETH W                       NaN                  NaN
# COLWELL WESLEY                  1200000.0                  NaN
# CORDES WILLIAM R                      NaN                  NaN
# COX DAVID                        800000.0                  NaN
# CUMBERLAND MICHAEL S             325000.0             275000.0
# ...                                   ...                  ...
# SHANKMAN JEFFREY A              2000000.0             554422.0
# SHAPIRO RICHARD S                650000.0                  NaN
# SHARP VICTORIA T                 600000.0             422158.0
# SHELBY REX                       200000.0                  NaN
# SHERRICK JEFFREY B                    NaN                  NaN
# SHERRIFF JOHN R                 1500000.0             554422.0
# SKILLING JEFFREY K              5600000.0            1920000.0
# STABLER FRANK                    500000.0                  NaN
# SULLIVAN-SHAKLOVITZ COLLEEN      100000.0             554422.0
# SUNDE MARTIN                     700000.0             476451.0
# TAYLOR MITCHELL S                600000.0                  NaN
# THE TRAVEL AGENCY IN THE PARK         NaN                  NaN
# THORN TERENCE H                       NaN             200000.0
# TILNEY ELIZABETH A               300000.0             275000.0
# TOTAL                          97343619.0           48521928.0
# UMANOFF ADAM S                   788750.0                  NaN
# URQUHART JOHN A                       NaN                  NaN
# WAKEHAM JOHN                          NaN                  NaN
# WALLS JR ROBERT H                850000.0             540751.0
# WALTERS GARETH W                      NaN                  NaN
# WASAFF GEORGE                    325000.0             200000.0
# WESTFAHL RICHARD K                    NaN             256191.0
# WHALEY DAVID A                        NaN                  NaN
# WHALLEY LAWRENCE G              3000000.0             808346.0
# WHITE JR THOMAS E                450000.0                  NaN
# WINOKUR JR. HERBERT S                 NaN                  NaN
# WODRASKA JOHN                         NaN                  NaN
# WROBEL BRUCE                          NaN                  NaN
# YEAGER F SCOTT                        NaN                  NaN
# YEAP SOON                             NaN                  NaN
#
#                                      ...          deferral_payments  \
# ALLEN PHILLIP K                      ...                  2869717.0
# BADUM JAMES P                        ...                   178980.0
# BANNANTINE JAMES M                   ...                        NaN
# BAXTER JOHN C                        ...                  1295738.0
# BAY FRANKLIN R                       ...                   260455.0
# BAZELIDES PHILIP J                   ...                   684694.0
# BECK SALLY W                         ...                        NaN
# BELDEN TIMOTHY N                     ...                  2144013.0
# BELFER ROBERT                        ...                  -102500.0
# BERBERIAN DAVID                      ...                        NaN
# BERGSIEKER RICHARD P                 ...                        NaN
# BHATNAGAR SANJAY                     ...                        NaN
# BIBI PHILIPPE A                      ...                        NaN
# BLACHMAN JEREMY M                    ...                        NaN
# BLAKE JR. NORMAN P                   ...                        NaN
# BOWEN JR RAYMOND M                   ...                        NaN
# BROWN MICHAEL                        ...                        NaN
# BUCHANAN HAROLD G                    ...                        NaN
# BUTTS ROBERT H                       ...                        NaN
# BUY RICHARD B                        ...                   649584.0
# CALGER CHRISTOPHER F                 ...                        NaN
# CARTER REBECCA C                     ...                        NaN
# CAUSEY RICHARD A                     ...                        NaN
# CHAN RONNIE                          ...                        NaN
# CHRISTODOULOU DIOMEDES               ...                        NaN
# CLINE KENNETH W                      ...                        NaN
# COLWELL WESLEY                       ...                    27610.0
# CORDES WILLIAM R                     ...                        NaN
# COX DAVID                            ...                        NaN
# CUMBERLAND MICHAEL S                 ...                        NaN
# ...                                  ...                        ...
# SHANKMAN JEFFREY A                   ...                        NaN
# SHAPIRO RICHARD S                    ...                        NaN
# SHARP VICTORIA T                     ...                   187469.0
# SHELBY REX                           ...                        NaN
# SHERRICK JEFFREY B                   ...                        NaN
# SHERRIFF JOHN R                      ...                        NaN
# SKILLING JEFFREY K                   ...                        NaN
# STABLER FRANK                        ...                        NaN
# SULLIVAN-SHAKLOVITZ COLLEEN          ...                   181993.0
# SUNDE MARTIN                         ...                        NaN
# TAYLOR MITCHELL S                    ...                   227449.0
# THE TRAVEL AGENCY IN THE PARK        ...                        NaN
# THORN TERENCE H                      ...                    16586.0
# TILNEY ELIZABETH A                   ...                        NaN
# TOTAL                                ...                 32083396.0
# UMANOFF ADAM S                       ...                        NaN
# URQUHART JOHN A                      ...                        NaN
# WAKEHAM JOHN                         ...                        NaN
# WALLS JR ROBERT H                    ...                        NaN
# WALTERS GARETH W                     ...                    53625.0
# WASAFF GEORGE                        ...                   831299.0
# WESTFAHL RICHARD K                   ...                        NaN
# WHALEY DAVID A                       ...                        NaN
# WHALLEY LAWRENCE G                   ...                        NaN
# WHITE JR THOMAS E                    ...                        NaN
# WINOKUR JR. HERBERT S                ...                        NaN
# WODRASKA JOHN                        ...                        NaN
# WROBEL BRUCE                         ...                        NaN
# YEAGER F SCOTT                       ...                        NaN
# YEAP SOON                            ...                        NaN
#
#                                loan_advances       other   expenses  \
# ALLEN PHILLIP K                          NaN       152.0    13868.0
# BADUM JAMES P                            NaN         NaN     3486.0
# BANNANTINE JAMES M                       NaN    864523.0    56301.0
# BAXTER JOHN C                            NaN   2660303.0    11200.0
# BAY FRANKLIN R                           NaN        69.0   129142.0
# BAZELIDES PHILIP J                       NaN       874.0        NaN
# BECK SALLY W                             NaN       566.0    37172.0
# BELDEN TIMOTHY N                         NaN    210698.0    17355.0
# BELFER ROBERT                            NaN         NaN        NaN
# BERBERIAN DAVID                          NaN         NaN    11892.0
# BERGSIEKER RICHARD P                     NaN    427316.0    59175.0
# BHATNAGAR SANJAY                         NaN    137864.0        NaN
# BIBI PHILIPPE A                          NaN    425688.0    38559.0
# BLACHMAN JEREMY M                        NaN       272.0    84208.0
# BLAKE JR. NORMAN P                       NaN         NaN     1279.0
# BOWEN JR RAYMOND M                       NaN      1621.0    65907.0
# BROWN MICHAEL                            NaN         NaN    49288.0
# BUCHANAN HAROLD G                        NaN      1215.0      600.0
# BUTTS ROBERT H                           NaN    150656.0     9410.0
# BUY RICHARD B                            NaN    400572.0        NaN
# CALGER CHRISTOPHER F                     NaN       486.0    35818.0
# CARTER REBECCA C                         NaN       540.0        NaN
# CAUSEY RICHARD A                         NaN    307895.0    30674.0
# CHAN RONNIE                              NaN         NaN        NaN
# CHRISTODOULOU DIOMEDES                   NaN         NaN        NaN
# CLINE KENNETH W                          NaN         NaN        NaN
# COLWELL WESLEY                           NaN    101740.0    16514.0
# CORDES WILLIAM R                         NaN         NaN        NaN
# COX DAVID                                NaN       494.0    27861.0
# CUMBERLAND MICHAEL S                     NaN       713.0    22344.0
# ...                                      ...         ...        ...
# SHANKMAN JEFFREY A                       NaN      1191.0   178979.0
# SHAPIRO RICHARD S                        NaN       705.0   137767.0
# SHARP VICTORIA T                         NaN      2401.0   116337.0
# SHELBY REX                               NaN   1573324.0    22884.0
# SHERRICK JEFFREY B                       NaN         NaN        NaN
# SHERRIFF JOHN R                          NaN   1852186.0        NaN
# SKILLING JEFFREY K                       NaN     22122.0    29336.0
# STABLER FRANK                            NaN    356071.0    16514.0
# SULLIVAN-SHAKLOVITZ COLLEEN              NaN       162.0        NaN
# SUNDE MARTIN                             NaN    111122.0        NaN
# TAYLOR MITCHELL S                        NaN         NaN        NaN
# THE TRAVEL AGENCY IN THE PARK            NaN    362096.0        NaN
# THORN TERENCE H                          NaN    426629.0    46145.0
# TILNEY ELIZABETH A                       NaN    152055.0        NaN
# TOTAL                             83925000.0  42667589.0  5235198.0
# UMANOFF ADAM S                           NaN         NaN    53122.0
# URQUHART JOHN A                          NaN         NaN   228656.0
# WAKEHAM JOHN                             NaN         NaN   103773.0
# WALLS JR ROBERT H                        NaN         2.0    50936.0
# WALTERS GARETH W                         NaN         NaN    33785.0
# WASAFF GEORGE                            NaN      1425.0        NaN
# WESTFAHL RICHARD K                       NaN    401130.0    51870.0
# WHALEY DAVID A                           NaN         NaN        NaN
# WHALLEY LAWRENCE G                       NaN    301026.0    57838.0
# WHITE JR THOMAS E                        NaN   1085463.0    81353.0
# WINOKUR JR. HERBERT S                    NaN         NaN     1413.0
# WODRASKA JOHN                            NaN    189583.0        NaN
# WROBEL BRUCE                             NaN         NaN        NaN
# YEAGER F SCOTT                           NaN    147950.0    53947.0
# YEAP SOON                                NaN         NaN    55097.0
#
#                                director_fees  total_payments  \
# ALLEN PHILLIP K                          NaN       4484442.0
# BADUM JAMES P                            NaN        182466.0
# BANNANTINE JAMES M                       NaN        916197.0
# BAXTER JOHN C                            NaN       5634343.0
# BAY FRANKLIN R                           NaN        827696.0
# BAZELIDES PHILIP J                       NaN        860136.0
# BECK SALLY W                             NaN        969068.0
# BELDEN TIMOTHY N                         NaN       5501630.0
# BELFER ROBERT                         3285.0        102500.0
# BERBERIAN DAVID                          NaN        228474.0
# BERGSIEKER RICHARD P                     NaN        618850.0
# BHATNAGAR SANJAY                    137864.0      15456290.0
# BIBI PHILIPPE A                          NaN       2047593.0
# BLACHMAN JEREMY M                        NaN       2014835.0
# BLAKE JR. NORMAN P                  113784.0          1279.0
# BOWEN JR RAYMOND M                       NaN       2669589.0
# BROWN MICHAEL                            NaN         49288.0
# BUCHANAN HAROLD G                        NaN       1054637.0
# BUTTS ROBERT H                           NaN       1271582.0
# BUY RICHARD B                            NaN       2355702.0
# CALGER CHRISTOPHER F                     NaN       1639297.0
# CARTER REBECCA C                         NaN        477557.0
# CAUSEY RICHARD A                         NaN       1868758.0
# CHAN RONNIE                          98784.0             NaN
# CHRISTODOULOU DIOMEDES                   NaN             NaN
# CLINE KENNETH W                          NaN             NaN
# COLWELL WESLEY                           NaN       1490344.0
# CORDES WILLIAM R                         NaN             NaN
# COX DAVID                                NaN       1101393.0
# CUMBERLAND MICHAEL S                     NaN        807956.0
# ...                                      ...             ...
# SHANKMAN JEFFREY A                       NaN       3038702.0
# SHAPIRO RICHARD S                        NaN       1057548.0
# SHARP VICTORIA T                         NaN       1576511.0
# SHELBY REX                               NaN       2003885.0
# SHERRICK JEFFREY B                       NaN             NaN
# SHERRIFF JOHN R                          NaN       4335388.0
# SKILLING JEFFREY K                       NaN       8682716.0
# STABLER FRANK                            NaN       1112087.0
# SULLIVAN-SHAKLOVITZ COLLEEN              NaN        999356.0
# SUNDE MARTIN                             NaN       1545059.0
# TAYLOR MITCHELL S                        NaN       1092663.0
# THE TRAVEL AGENCY IN THE PARK            NaN        362096.0
# THORN TERENCE H                          NaN        911453.0
# TILNEY ELIZABETH A                       NaN        399393.0
# TOTAL                              1398517.0     309886585.0
# UMANOFF ADAM S                           NaN       1130461.0
# URQUHART JOHN A                      36666.0        228656.0
# WAKEHAM JOHN                        109298.0        213071.0
# WALLS JR ROBERT H                        NaN       1798780.0
# WALTERS GARETH W                         NaN         87410.0
# WASAFF GEORGE                            NaN       1034395.0
# WESTFAHL RICHARD K                       NaN        762135.0
# WHALEY DAVID A                           NaN             NaN
# WHALLEY LAWRENCE G                       NaN       4677574.0
# WHITE JR THOMAS E                        NaN       1934359.0
# WINOKUR JR. HERBERT S               108579.0         84992.0
# WODRASKA JOHN                            NaN        189583.0
# WROBEL BRUCE                             NaN             NaN
# YEAGER F SCOTT                           NaN        360300.0
# YEAP SOON                                NaN         55097.0
#
#                                exercised_stock_options  restricted_stock  \
# ALLEN PHILLIP K                              1729541.0          126027.0
# BADUM JAMES P                                 257817.0               NaN
# BANNANTINE JAMES M                           4046157.0         1757552.0
# BAXTER JOHN C                                6680544.0         3942714.0
# BAY FRANKLIN R                                     NaN          145796.0
# BAZELIDES PHILIP J                           1599641.0               NaN
# BECK SALLY W                                       NaN          126027.0
# BELDEN TIMOTHY N                              953136.0          157569.0
# BELFER ROBERT                                   3285.0               NaN
# BERBERIAN DAVID                              1624396.0          869220.0
# BERGSIEKER RICHARD P                               NaN          659249.0
# BHATNAGAR SANJAY                             2604490.0        -2604490.0
# BIBI PHILIPPE A                              1465734.0          378082.0
# BLACHMAN JEREMY M                             765313.0          189041.0
# BLAKE JR. NORMAN P                                 NaN               NaN
# BOWEN JR RAYMOND M                                 NaN          252055.0
# BROWN MICHAEL                                      NaN               NaN
# BUCHANAN HAROLD G                             825464.0          189041.0
# BUTTS ROBERT H                                     NaN          417619.0
# BUY RICHARD B                                2542813.0          901657.0
# CALGER CHRISTOPHER F                               NaN          126027.0
# CARTER REBECCA C                                   NaN          307301.0
# CAUSEY RICHARD A                                   NaN         2502063.0
# CHAN RONNIE                                        NaN           32460.0
# CHRISTODOULOU DIOMEDES                       5127155.0          950730.0
# CLINE KENNETH W                                    NaN          662086.0
# COLWELL WESLEY                                     NaN          698242.0
# CORDES WILLIAM R                              651850.0          386335.0
# COX DAVID                                     117551.0          378082.0
# CUMBERLAND MICHAEL S                               NaN          207940.0
# ...                                                ...               ...
# SHANKMAN JEFFREY A                           1441898.0          630137.0
# SHAPIRO RICHARD S                             607837.0          379164.0
# SHARP VICTORIA T                              281073.0          213063.0
# SHELBY REX                                   1624396.0          869220.0
# SHERRICK JEFFREY B                           1426469.0          405999.0
# SHERRIFF JOHN R                              1835558.0         1293424.0
# SKILLING JEFFREY K                          19250000.0         6843672.0
# STABLER FRANK                                      NaN          511734.0
# SULLIVAN-SHAKLOVITZ COLLEEN                  1362375.0               NaN
# SUNDE MARTIN                                       NaN          698920.0
# TAYLOR MITCHELL S                            3181250.0          563798.0
# THE TRAVEL AGENCY IN THE PARK                      NaN               NaN
# THORN TERENCE H                              4452476.0          365320.0
# TILNEY ELIZABETH A                            591250.0          576792.0
# TOTAL                                      311764000.0       130322299.0
# UMANOFF ADAM S                                     NaN               NaN
# URQUHART JOHN A                                    NaN               NaN
# WAKEHAM JOHN                                       NaN               NaN
# WALLS JR ROBERT H                            4346544.0         1552453.0
# WALTERS GARETH W                             1030329.0               NaN
# WASAFF GEORGE                                1668260.0          388167.0
# WESTFAHL RICHARD K                                 NaN          384930.0
# WHALEY DAVID A                                 98718.0               NaN
# WHALLEY LAWRENCE G                           3282960.0         2796177.0
# WHITE JR THOMAS E                            1297049.0        13847074.0
# WINOKUR JR. HERBERT S                              NaN               NaN
# WODRASKA JOHN                                      NaN               NaN
# WROBEL BRUCE                                  139130.0               NaN
# YEAGER F SCOTT                               8308552.0         3576206.0
# YEAP SOON                                     192758.0               NaN
#
#                                restricted_stock_deferred  total_stock_value
# ALLEN PHILLIP K                                -126027.0          1729541.0
# BADUM JAMES P                                        NaN           257817.0
# BANNANTINE JAMES M                             -560222.0          5243487.0
# BAXTER JOHN C                                        NaN         10623258.0
# BAY FRANKLIN R                                  -82782.0            63014.0
# BAZELIDES PHILIP J                                   NaN          1599641.0
# BECK SALLY W                                         NaN           126027.0
# BELDEN TIMOTHY N                                     NaN          1110705.0
# BELFER ROBERT                                    44093.0           -44093.0
# BERBERIAN DAVID                                      NaN          2493616.0
# BERGSIEKER RICHARD P                                 NaN           659249.0
# BHATNAGAR SANJAY                              15456290.0                NaN
# BIBI PHILIPPE A                                      NaN          1843816.0
# BLACHMAN JEREMY M                                    NaN           954354.0
# BLAKE JR. NORMAN P                                   NaN                NaN
# BOWEN JR RAYMOND M                                   NaN           252055.0
# BROWN MICHAEL                                        NaN                NaN
# BUCHANAN HAROLD G                                    NaN          1014505.0
# BUTTS ROBERT H                                       NaN           417619.0
# BUY RICHARD B                                        NaN          3444470.0
# CALGER CHRISTOPHER F                                 NaN           126027.0
# CARTER REBECCA C                               -307301.0                NaN
# CAUSEY RICHARD A                                     NaN          2502063.0
# CHAN RONNIE                                     -32460.0                NaN
# CHRISTODOULOU DIOMEDES                               NaN          6077885.0
# CLINE KENNETH W                                -472568.0           189518.0
# COLWELL WESLEY                                       NaN           698242.0
# CORDES WILLIAM R                                     NaN          1038185.0
# COX DAVID                                            NaN           495633.0
# CUMBERLAND MICHAEL S                                 NaN           207940.0
# ...                                                  ...                ...
# SHANKMAN JEFFREY A                                   NaN          2072035.0
# SHAPIRO RICHARD S                                    NaN           987001.0
# SHARP VICTORIA T                                     NaN           494136.0
# SHELBY REX                                           NaN          2493616.0
# SHERRICK JEFFREY B                                   NaN          1832468.0
# SHERRIFF JOHN R                                      NaN          3128982.0
# SKILLING JEFFREY K                                   NaN         26093672.0
# STABLER FRANK                                        NaN           511734.0
# SULLIVAN-SHAKLOVITZ COLLEEN                          NaN          1362375.0
# SUNDE MARTIN                                         NaN           698920.0
# TAYLOR MITCHELL S                                    NaN          3745048.0
# THE TRAVEL AGENCY IN THE PARK                        NaN                NaN
# THORN TERENCE H                                      NaN          4817796.0
# TILNEY ELIZABETH A                                   NaN          1168042.0
# TOTAL                                         -7576788.0        434509511.0
# UMANOFF ADAM S                                       NaN                NaN
# URQUHART JOHN A                                      NaN                NaN
# WAKEHAM JOHN                                         NaN                NaN
# WALLS JR ROBERT H                                    NaN          5898997.0
# WALTERS GARETH W                                     NaN          1030329.0
# WASAFF GEORGE                                        NaN          2056427.0
# WESTFAHL RICHARD K                                   NaN           384930.0
# WHALEY DAVID A                                       NaN            98718.0
# WHALLEY LAWRENCE G                                   NaN          6079137.0
# WHITE JR THOMAS E                                    NaN         15144123.0
# WINOKUR JR. HERBERT S                                NaN                NaN
# WODRASKA JOHN                                        NaN                NaN
# WROBEL BRUCE                                         NaN           139130.0
# YEAGER F SCOTT                                       NaN         11884758.0
# YEAP SOON                                            NaN           192758.0
#
# [146 rows x 21 columns]

# %% [markdown]
# ### Add ratios of email & receipt sharing with poi's to df
# The ratio of emails send/recieved to/by pois compared to all emails that were send. The total amount of mails send by pois

# %%
# calculate ratio
df['recieved_from_poi_ratio'] = df['from_poi_to_this_person'] / df['to_messages']
df['sent_to_poi_ratio'] = df['from_this_person_to_poi'] / df['from_messages']
df['shared_receipt_with_poi_ratio'] = df['shared_receipt_with_poi'] / df['to_messages']
# add labels to df
features_email_new = ['recieved_from_poi_ratio', 'sent_to_poi_ratio', 'shared_receipt_with_poi_ratio']
features_all = features_list + features_email_new

# %% [markdown]
# ### Remove invalid columns
# The `TOTAL` and `THE TRAVEL AGENCY IN THE PARK` column are mistakes in the dataset as discovered and discussed during the Nanodegree course. They'll be removed here as well – for reference please check the ML course in Udacity.

# %%
df = df[df.index != 'TOTAL']
df = df[df.index != 'THE TRAVEL AGENCY IN THE PARK']

# %% [markdown]
# ### Shape of the table:

# %%
#Dataset Shape:
df.shape
# Out:
# (144, 24)

# %% [markdown]
# The shape of the dataset shows that there are 144 rows (persons) and 24 columns (features) of which 3 are the interaction with POS ratios that were just added.

# %% [markdown]
# ### Missing features

# %%
df_null_value_ratio = (df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
df_null_values = (df.isnull().sum()).sort_values(ascending=False)
frames = [df_null_values, df_null_value_ratio]
print pd.concat(frames, axis=1, join_axes=[df_null_values.index])
# Out:
#                                  0         1
# loan_advances                  141  0.979167
# director_fees                  128  0.888889
# restricted_stock_deferred      127  0.881944
# deferral_payments              106  0.736111
# deferred_income                 96  0.666667
# long_term_incentive             79  0.548611
# bonus                           63  0.437500
# to_messages                     58  0.402778
# from_messages                   58  0.402778
# from_poi_to_this_person         58  0.402778
# from_this_person_to_poi         58  0.402778
# shared_receipt_with_poi         58  0.402778
# shared_receipt_with_poi_ratio   58  0.402778
# sent_to_poi_ratio               58  0.402778
# recieved_from_poi_ratio         58  0.402778
# other                           53  0.368056
# expenses                        50  0.347222
# salary                          50  0.347222
# exercised_stock_options         43  0.298611
# restricted_stock                35  0.243056
# total_payments                  21  0.145833
# total_stock_value               19  0.131944
# email_address                    0  0.000000
# poi                              0  0.000000

# %% [markdown]
# This is good news! Even though there are features missing, there is a poi flag and email address for each person in the dataset.

# %% [markdown]
# ### POI characteristics

# %%
# count number of pois
print 'Number of POIs:'
print df.loc[df['poi'] == True].count().sort_values()
# Out:
# Number of POIs:
# restricted_stock_deferred         0
# director_fees                     0
# loan_advances                     1
# deferral_payments                 5
# deferred_income                  11
# exercised_stock_options          12
# long_term_incentive              12
# recieved_from_poi_ratio          14
# sent_to_poi_ratio                14
# shared_receipt_with_poi_ratio    14
# shared_receipt_with_poi          14
# from_this_person_to_poi          14
# from_poi_to_this_person          14
# from_messages                    14
# to_messages                      14
# bonus                            16
# salary                           17
# restricted_stock                 17
# other                            18
# expenses                         18
# total_payments                   18
# total_stock_value                18
# email_address                    18
# poi                              18
# dtype: int64

# %% [markdown]
# The table above shows the number of poi's as well as the count of available values per feature. At first I was very happy about those features that were missing for all POI's until I realized that those are also missing for the rest of the dataset.
#
# POI's only make up for 12.5% of our dataset, so there is a skewed distribution. This needs to be considered when evaluating the classification algos. If an algo such as POI = False would be deployed the accuracy would already be at 86%. Developing an algorithm with a accurady of 86% in less than 5 minutes does not sound too bad – but doesn't help in identifying the POIs at all.

# %% [markdown]
# ### Positional Parameters
# Defined as outliers above Q3 + 1.5 IQR and Q3 + 3 IQR, respectively.

# %%
print df.describe()
# Out:
#         to_messages  from_messages  from_poi_to_this_person  \
# count     86.000000      86.000000                86.000000
# mean    2073.860465     608.790698                64.895349
# std     2582.700981    1841.033949                86.979244
# min       57.000000      12.000000                 0.000000
# 25%      541.250000      22.750000                10.000000
# 50%     1211.000000      41.000000                35.000000
# 75%     2634.750000     145.500000                72.250000
# max    15149.000000   14368.000000               528.000000
#
#        from_this_person_to_poi  shared_receipt_with_poi        salary  \
# count                86.000000                86.000000  9.400000e+01
# mean                 41.232558              1176.465116  2.840875e+05
# std                 100.073111              1178.317641  1.771311e+05
# min                   0.000000                 2.000000  4.770000e+02
# 25%                   1.000000               249.750000  2.118020e+05
# 50%                   8.000000               740.500000  2.587410e+05
# 75%                  24.750000              1888.250000  3.086065e+05
# max                 609.000000              5521.000000  1.111258e+06
#
#               bonus  long_term_incentive  deferred_income  deferral_payments  \
# count  8.100000e+01         6.500000e+01     4.800000e+01       3.800000e+01
# mean   1.201773e+06         7.464912e+05    -5.810498e+05       8.416025e+05
# std    1.441679e+06         8.629174e+05     9.420764e+05       1.289323e+06
# min    7.000000e+04         6.922300e+04    -3.504386e+06      -1.025000e+05
# 25%    4.250000e+05         2.750000e+05    -6.112092e+05       7.964450e+04
# 50%    7.500000e+05         4.221580e+05    -1.519270e+05       2.210635e+05
# 75%    1.200000e+06         8.318090e+05    -3.792600e+04       8.672112e+05
# max    8.000000e+06         5.145434e+06    -8.330000e+02       6.426990e+06
#
#                    ...                     expenses  director_fees  \
# count              ...                    94.000000      16.000000
# mean               ...                 54192.010638   89822.875000
# std                ...                 46108.377454   41112.700735
# min                ...                   148.000000    3285.000000
# 25%                ...                 22479.000000   83674.500000
# 50%                ...                 46547.500000  106164.500000
# 75%                ...                 78408.500000  112815.000000
# max                ...                228763.000000  137864.000000
#
#        total_payments  exercised_stock_options  restricted_stock  \
# count    1.230000e+02             1.010000e+02      1.090000e+02
# mean     2.641806e+06             2.959559e+06      1.147424e+06
# std      9.524694e+06             5.499450e+06      2.249770e+06
# min      1.480000e+02             3.285000e+03     -2.604490e+06
# 25%      3.969340e+05             5.067650e+05      2.520550e+05
# 50%      1.101393e+06             1.297049e+06      4.410960e+05
# 75%      2.087530e+06             2.542813e+06      9.850320e+05
# max      1.035598e+08             3.434838e+07      1.476169e+07
#
#        restricted_stock_deferred  total_stock_value  recieved_from_poi_ratio  \
# count               1.700000e+01       1.250000e+02                86.000000
# mean                6.218928e+05       3.352073e+06                 0.037963
# std                 3.845528e+06       6.532883e+06                 0.040544
# min                -1.787380e+06      -4.409300e+04                 0.000000
# 25%                -3.298250e+05       4.941360e+05                 0.009200
# 50%                -1.402640e+05       1.095040e+06                 0.025845
# 75%                -7.241900e+04       2.606763e+06                 0.056089
# max                 1.545629e+07       4.911008e+07                 0.217341
#
#        sent_to_poi_ratio  shared_receipt_with_poi_ratio
# count          86.000000                      86.000000
# mean            0.184055                       0.609058
# std             0.210610                       0.287300
# min             0.000000                       0.018377
# 25%             0.012421                       0.413779
# 50%             0.100574                       0.661044
# 75%             0.272039                       0.841199
# max             1.000000                       1.001145
#
# [8 rows x 22 columns]

# %% [markdown]
# #### Outlier and extreme value detection

# %% [markdown]
# ### Correlation coefficients:

# %%
print df.corr()
# Out:
#                                     poi  to_messages  from_messages  \
# poi                            1.000000     0.058954      -0.074308
# to_messages                    0.058954     1.000000       0.475450
# from_messages                 -0.074308     0.475450       1.000000
# from_poi_to_this_person        0.167722     0.525667       0.186708
# from_this_person_to_poi        0.112940     0.568506       0.588687
# shared_receipt_with_poi        0.228313     0.847990       0.230855
# salary                         0.264976     0.187047      -0.003541
# bonus                          0.302384     0.372997       0.052725
# long_term_incentive            0.254723     0.134277      -0.071958
# deferred_income               -0.265698    -0.350815      -0.319995
# deferral_payments             -0.098428     0.310129       0.321947
# loan_advances                  0.999851     0.739805      -0.213768
# other                          0.120270     0.040580      -0.101686
# expenses                       0.060292     0.155070       0.094144
# director_fees                       NaN    -1.000000       1.000000
# total_payments                 0.230102     0.133834      -0.033089
# exercised_stock_options        0.503551     0.079568      -0.066129
# restricted_stock               0.224814     0.195570       0.003145
# restricted_stock_deferred           NaN    -0.359420      -0.326671
# total_stock_value              0.366462     0.120864      -0.036310
# recieved_from_poi_ratio        0.104406    -0.133672      -0.130654
# sent_to_poi_ratio              0.339938    -0.126446      -0.184793
# shared_receipt_with_poi_ratio  0.265225    -0.118133      -0.263854
#
#                                from_poi_to_this_person  \
# poi                                           0.167722
# to_messages                                   0.525667
# from_messages                                 0.186708
# from_poi_to_this_person                       1.000000
# from_this_person_to_poi                       0.445063
# shared_receipt_with_poi                       0.659264
# salary                                        0.179055
# bonus                                         0.562187
# long_term_incentive                           0.212538
# deferred_income                              -0.178951
# deferral_payments                             0.424101
# loan_advances                                 0.009878
# other                                         0.111249
# expenses                                     -0.059244
# director_fees                                      NaN
# total_payments                                0.154431
# exercised_stock_options                       0.160253
# restricted_stock                              0.133594
# restricted_stock_deferred                    -0.455876
# total_stock_value                             0.146366
# recieved_from_poi_ratio                       0.468983
# sent_to_poi_ratio                             0.062690
# shared_receipt_with_poi_ratio                 0.137895
#
#                                from_this_person_to_poi  \
# poi                                           0.112940
# to_messages                                   0.568506
# from_messages                                 0.588687
# from_poi_to_this_person                       0.445063
# from_this_person_to_poi                       1.000000
# shared_receipt_with_poi                       0.475748
# salary                                        0.021288
# bonus                                         0.354634
# long_term_incentive                           0.083591
# deferred_income                              -0.271673
# deferral_payments                             0.206993
# loan_advances                                 0.934835
# other                                        -0.110335
# expenses                                      0.014964
# director_fees                                 1.000000
# total_payments                                0.011556
# exercised_stock_options                      -0.030101
# restricted_stock                              0.049284
# restricted_stock_deferred                    -0.398550
# total_stock_value                             0.001289
# recieved_from_poi_ratio                      -0.052852
# sent_to_poi_ratio                            -0.046771
# shared_receipt_with_poi_ratio                -0.101448
#
#                                shared_receipt_with_poi    salary     bonus  \
# poi                                           0.228313  0.264976  0.302384
# to_messages                                   0.847990  0.187047  0.372997
# from_messages                                 0.230855 -0.003541  0.052725
# from_poi_to_this_person                       0.659264  0.179055  0.562187
# from_this_person_to_poi                       0.475748  0.021288  0.354634
# shared_receipt_with_poi                       1.000000  0.284995  0.549102
# salary                                        0.284995  1.000000  0.523190
# bonus                                         0.549102  0.523190  1.000000
# long_term_incentive                           0.178944  0.484114  0.625259
# deferred_income                              -0.394677 -0.353816 -0.411659
# deferral_payments                             0.356696  0.455884  0.293543
# loan_advances                                 0.291501  0.535252  0.973826
# other                                         0.122591  0.606903  0.376371
# expenses                                      0.223495  0.145364  0.033799
# director_fees                                 1.000000       NaN       NaN
# total_payments                                0.191069  0.579260  0.569054
# exercised_stock_options                       0.154333  0.607324  0.506998
# restricted_stock                              0.232660  0.550824  0.376992
# restricted_stock_deferred                    -0.348405 -0.592576  0.118222
# total_stock_value                             0.176314  0.614736  0.509441
# recieved_from_poi_ratio                      -0.036665 -0.130777 -0.061878
# sent_to_poi_ratio                             0.037625  0.004715  0.068153
# shared_receipt_with_poi_ratio                 0.232536 -0.014912 -0.046763
#
#                                long_term_incentive  deferred_income  \
# poi                                       0.254723        -0.265698
# to_messages                               0.134277        -0.350815
# from_messages                            -0.071958        -0.319995
# from_poi_to_this_person                   0.212538        -0.178951
# from_this_person_to_poi                   0.083591        -0.271673
# shared_receipt_with_poi                   0.178944        -0.394677
# salary                                    0.484114        -0.353816
# bonus                                     0.625259        -0.411659
# long_term_incentive                       1.000000        -0.331715
# deferred_income                          -0.331715         1.000000
# deferral_payments                         0.042448        -0.881500
# loan_advances                             1.000000         1.000000
# other                                     0.529398        -0.185219
# expenses                                 -0.100766         0.101181
# director_fees                                  NaN        -0.464837
# total_payments                            0.518498        -0.054404
# exercised_stock_options                   0.500016        -0.308076
# restricted_stock                          0.635172        -0.133895
# restricted_stock_deferred                -0.186597         0.173154
# total_stock_value                         0.495485        -0.298189
# recieved_from_poi_ratio                   0.009281         0.148719
# sent_to_poi_ratio                         0.027852        -0.019555
# shared_receipt_with_poi_ratio            -0.059715        -0.246825
#
#                                            ...                expenses  \
# poi                                        ...                0.060292
# to_messages                                ...                0.155070
# from_messages                              ...                0.094144
# from_poi_to_this_person                    ...               -0.059244
# from_this_person_to_poi                    ...                0.014964
# shared_receipt_with_poi                    ...                0.223495
# salary                                     ...                0.145364
# bonus                                      ...                0.033799
# long_term_incentive                        ...               -0.100766
# deferred_income                            ...                0.101181
# deferral_payments                          ...                0.004800
# loan_advances                              ...                0.658681
# other                                      ...                0.062874
# expenses                                   ...                1.000000
# director_fees                              ...               -0.504631
# total_payments                             ...                0.109798
# exercised_stock_options                    ...                0.019412
# restricted_stock                           ...                0.042896
# restricted_stock_deferred                  ...                0.040947
# total_stock_value                          ...                0.034707
# recieved_from_poi_ratio                    ...               -0.118860
# sent_to_poi_ratio                          ...               -0.133905
# shared_receipt_with_poi_ratio              ...                0.197029
#
#                                director_fees  total_payments  \
# poi                                      NaN        0.230102
# to_messages                        -1.000000        0.133834
# from_messages                       1.000000       -0.033089
# from_poi_to_this_person                  NaN        0.154431
# from_this_person_to_poi             1.000000        0.011556
# shared_receipt_with_poi             1.000000        0.191069
# salary                                   NaN        0.579260
# bonus                                    NaN        0.569054
# long_term_incentive                      NaN        0.518498
# deferred_income                    -0.464837       -0.054404
# deferral_payments                        NaN        0.066774
# loan_advances                            NaN        0.991879
# other                                    NaN        0.825589
# expenses                           -0.504631        0.109798
# director_fees                       1.000000        0.317360
# total_payments                      0.317360        1.000000
# exercised_stock_options             0.623257        0.591690
# restricted_stock                   -0.968483        0.595728
# restricted_stock_deferred           0.575257        0.941613
# total_stock_value                   0.997476        0.668166
# recieved_from_poi_ratio                  NaN       -0.043807
# sent_to_poi_ratio                   1.000000        0.129631
# shared_receipt_with_poi_ratio       1.000000       -0.002824
#
#                                exercised_stock_options  restricted_stock  \
# poi                                           0.503551          0.224814
# to_messages                                   0.079568          0.195570
# from_messages                                -0.066129          0.003145
# from_poi_to_this_person                       0.160253          0.133594
# from_this_person_to_poi                      -0.030101          0.049284
# shared_receipt_with_poi                       0.154333          0.232660
# salary                                        0.607324          0.550824
# bonus                                         0.506998          0.376992
# long_term_incentive                           0.500016          0.635172
# deferred_income                              -0.308076         -0.133895
# deferral_payments                             0.019009          0.115088
# loan_advances                                 0.960259          1.000000
# other                                         0.536248          0.644357
# expenses                                      0.019412          0.042896
# director_fees                                 0.623257         -0.968483
# total_payments                                0.591690          0.595728
# exercised_stock_options                       1.000000          0.690935
# restricted_stock                              0.690935          1.000000
# restricted_stock_deferred                    -0.051644         -0.867102
# total_stock_value                             0.963560          0.855250
# recieved_from_poi_ratio                       0.020597         -0.039600
# sent_to_poi_ratio                             0.135990          0.163582
# shared_receipt_with_poi_ratio                 0.070133          0.031409
#
#                                restricted_stock_deferred  total_stock_value  \
# poi                                                  NaN           0.366462
# to_messages                                    -0.359420           0.120864
# from_messages                                  -0.326671          -0.036310
# from_poi_to_this_person                        -0.455876           0.146366
# from_this_person_to_poi                        -0.398550           0.001289
# shared_receipt_with_poi                        -0.348405           0.176314
# salary                                         -0.592576           0.614736
# bonus                                           0.118222           0.509441
# long_term_incentive                            -0.186597           0.495485
# deferred_income                                 0.173154          -0.298189
# deferral_payments                              -0.412777           0.075710
# loan_advances                                        NaN           0.962026
# other                                           0.011672           0.627171
# expenses                                        0.040947           0.034707
# director_fees                                   0.575257           0.997476
# total_payments                                  0.941613           0.668166
# exercised_stock_options                        -0.051644           0.963560
# restricted_stock                               -0.867102           0.855250
# restricted_stock_deferred                       1.000000          -0.819225
# total_stock_value                              -0.819225           1.000000
# recieved_from_poi_ratio                        -0.582503           0.004479
# sent_to_poi_ratio                              -0.178281           0.143280
# shared_receipt_with_poi_ratio                   0.640731           0.062354
#
#                                recieved_from_poi_ratio  sent_to_poi_ratio  \
# poi                                           0.104406           0.339938
# to_messages                                  -0.133672          -0.126446
# from_messages                                -0.130654          -0.184793
# from_poi_to_this_person                       0.468983           0.062690
# from_this_person_to_poi                      -0.052852          -0.046771
# shared_receipt_with_poi                      -0.036665           0.037625
# salary                                       -0.130777           0.004715
# bonus                                        -0.061878           0.068153
# long_term_incentive                           0.009281           0.027852
# deferred_income                               0.148719          -0.019555
# deferral_payments                             0.241365           0.202902
# loan_advances                                -0.189228           0.783924
# other                                        -0.017885           0.144407
# expenses                                     -0.118860          -0.133905
# director_fees                                      NaN           1.000000
# total_payments                               -0.043807           0.129631
# exercised_stock_options                       0.020597           0.135990
# restricted_stock                             -0.039600           0.163582
# restricted_stock_deferred                    -0.582503          -0.178281
# total_stock_value                             0.004479           0.143280
# recieved_from_poi_ratio                       1.000000           0.318313
# sent_to_poi_ratio                             0.318313           1.000000
# shared_receipt_with_poi_ratio                 0.344220           0.561406
#
#                                shared_receipt_with_poi_ratio
# poi                                                 0.265225
# to_messages                                        -0.118133
# from_messages                                      -0.263854
# from_poi_to_this_person                             0.137895
# from_this_person_to_poi                            -0.101448
# shared_receipt_with_poi                             0.232536
# salary                                             -0.014912
# bonus                                              -0.046763
# long_term_incentive                                -0.059715
# deferred_income                                    -0.246825
# deferral_payments                                   0.286156
# loan_advances                                      -0.955612
# other                                              -0.006239
# expenses                                            0.197029
# director_fees                                       1.000000
# total_payments                                     -0.002824
# exercised_stock_options                             0.070133
# restricted_stock                                    0.031409
# restricted_stock_deferred                           0.640731
# total_stock_value                                   0.062354
# recieved_from_poi_ratio                             0.344220
# sent_to_poi_ratio                                   0.561406
# shared_receipt_with_poi_ratio                       1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# ## References
#
# ### Articles
# * A look at those involved in the Enron scandal, USA Today - http://usatoday30.usatoday.com/money/industries/energy/2005-12-28-enron-participants_x.htm
# * The Immortal Life of the Enron E-mails, MIT Technology Review - https://www.technologyreview.com/s/515801/the-immortal-life-of-the-enron-e-mails/
# * Implementing a Weighted Majority Rule Ensemble Classifier in scikit-learn, Sebastian Raschka - http://sebastianraschka.com/Articles/2014_ensemble_classifier.html
# * Color Palettes in Seaborn, Chris Albon - http://chrisalbon.com/python/seaborn_color_palettes.html
# * Random Forests, Leo Breiman and Adele Cutler - http://www.stat.berkeley.edu/~breiman/RandomForests/cc_home.htm
# * Python sklearn.feature_selection.f_classif Examples - http://www.programcreek.com/python/example/85917/sklearn.feature_selection.f_classif
#
# ### Cheatsheets
# * Markdown - https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet
# * Pandas - https://github.com/pandas-dev/pandas/blob/master/doc/cheatsheet/Pandas_Cheat_Sheet.pdf
# * Numpy - https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Numpy_Python_Cheat_Sheet.pdf
#
# ### Documentation
# * Pipelining: chaining a PCA and a logistic regression, scikit learn - http://scikit-learn.org/stable/auto_examples/plot_digits_pipe.html
# * matplotlib.axes, matplotlib - http://matplotlib.org/api/axes_api.html
# * DataFrame quantiles, pandas - http://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.quantile.html
# * Visualization, pandas - https://pandas.pydata.org/pandas-docs/stable/visualization.html
# * pyplot, matplotlib - https://matplotlib.org/devdocs/api/_as_gen/matplotlib.pyplot.hist.html
# * sort values, pandas - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sort_values.html
# * Working with missing data, pandas - https://pandas.pydata.org/pandas-docs/stable/missing_data.html
#
# ### GitHub Repositories
# * EnsembleVoteClassifier, Sebastian Raschka - http://rasbt.github.io/mlxtend/user_guide/classifier/EnsembleVoteClassifier/
# * Grace Pehl: Identifying Persons of Interest from the Enron Corpus - https://github.com/grace-pehl/enron
# * brandjamie: Marchine Learning with the enron emails dataset - https://github.com/brandjamie/udacity_enron
# * Daria ALekseeva: Enron Dataset - https://github.com/DariaAlekseeva/Enron_Dataset
# * watanabe8760: uda-da-p5-enron-fraud-detection - https://github.com/watanabe8760/uda-da-p5-enron-fraud-detection
# * Mayukh Sobo: Enron Fraud https://github.com/MayukhSobo/EnronFraud
#
# ### Q&A pages
# * Pandas Replacement for .ix, Stack Overflow  - https://stackoverflow.com/questions/43838999/pandas-replacement-for-ix
# * Sci-kit and Regression Summary, Stack Overflow - http://stackoverflow.com/questions/26319259/sci-kit-and-regression-summary
# * How to obtain True Positive, True Negative, False Positive and False Negative, Stack Overflow - https://stackoverflow.com/questions/31324218/scikit-learn-how-to-obtain-true-positive-true-negative-false-positive-and-fal
# * Why do we need to normalize data before analysis, Cross Validated - http://stats.stackexchange.com/questions/69157/why-do-we-need-to-normalize-data-before-analysis
# * Perform feature normalization before or within model validation?, Cross Validated - http://stats.stackexchange.com/questions/77350/perform-feature-normalization-before-or-within-model-validation
# * How should the interquartile range be calculated in Python?, Stack Overflow - http://stackoverflow.com/questions/27472330/how-should-the-interquartile-range-be-calculated-in-python
# * scikit learn svc coef0 parameter range, Stack Overflow - http://stackoverflow.com/questions/21390570/scikit-learn-svc-coef0-parameter-range
# * What is a good range of values for the svm.SVC() hyperparameters to be explored via GridSearchCV()?, Stack Overflow - http://stackoverflow.com/questions/26337403/what-is-a-good-range-of-values-for-the-svm-svc-hyperparameters-to-be-explored
# * Imputation before or after splitting into train and test?, Cross Validated - http://stats.stackexchange.com/questions/95083/imputation-before-or-after-splitting-into-train-and-test
# * Is there a rule-of-thumb for how to divide a dataset into training and validation sets?, Stack Overflow - http://stackoverflow.com/questions/13610074/is-there-a-rule-of-thumb-for-how-to-divide-a-dataset-into-training-and-validatio
# * What is the difference between test set and validation set?, Cross Validated - http://stats.stackexchange.com/questions/19048/what-is-the-difference-between-test-set-and-validation-set
# * Python - What is exactly sklearn.pipeline.Pipeline?, Stack Overflow - http://stackoverflow.com/questions/33091376/python-what-is-exactly-sklearn-pipeline-pipeline
# * How can I use a custom feature selection function in scikit-learn's pipeline, Stack Overflow - http://stackoverflow.com/questions/25250654/how-can-i-use-a-custom-feature-selection-function-in-scikit-learns-pipeline
# * Seaborn distplot y-axis normalisation wrong ticklabels, Stack Overflow - http://stackoverflow.com/questions/32274865/seaborn-distplot-y-axis-normalisation-wrong-ticklabels
# * How to save a Seaborn plot into a file, Stack Overflow - http://stackoverflow.com/questions/32244753/how-to-save-a-seaborn-plot-into-a-file
# * Seaborn plots not showing up, Stack Overflow - https://stackoverflow.com/questions/26597116/seaborn-plots-not-showing-up
# * Select rows from a dataframe, Stack Overflow - https://stackoverflow.com/questions/17071871/select-rows-from-a-dataframe-based-on-values-in-a-column-in-pandas
#
# ### Tools
# * Markdown Tables Generator - http://www.tablesgenerator.com/markdown_tables
# * JSON pretty print - http://jsonprettyprint.com
#
# ### Wikipedia
# * Enron scandal - https://en.wikipedia.org/wiki/Enron_scandal
# * Boxplots - https://en.wikipedia.org/wiki/Box_plot
# * Interquartile range - https://en.wikipedia.org/wiki/Interquartile_range
# * False positive rate - https://en.wikipedia.org/wiki/False_positive_rate
# * False discovery rate - https://en.wikipedia.org/wiki/False_discovery_rate
# * Precision and recall - https://en.wikipedia.org/wiki/Precision_and_recall
